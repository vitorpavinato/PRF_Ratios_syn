# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

import pickle
from sfs_analyses import export_codonsfs_by_sample_size

# %%
# Unpickling a DataFrame
# %cd ../results/sfs
# !ls

with open('dgrp2_downsampled_sfss.pickle', 'rb') as file:
    downsampled_dgrp2_dict = pickle.load(file)


with open('dpgp3_downsampled_sfss.pickle', 'rb') as file:
    downsampled_dpgp3_dict = pickle.load(file)

# %%
# Export SFSs for a given sample size

# sample_size = 150
export_codonsfs_by_sample_size(downsampled_dgrp2_dict, 'dgrp2_downsampled_sfss.txt', 150)

export_codonsfs_by_sample_size(downsampled_dpgp3_dict, 'dpgp3_downsampled_sfss.txt', 150)

# sample_size = 25
# export_codonsfs_by_sample_size(downsampled_dgrp2_dict, 'dgrp2_downsampled_sfss.txt', 25)

# export_codonsfs_by_sample_size(downsampled_dpgp3_dict, 'dpgp3_downsampled_sfss.txt', 25)
# Out:
# Exporting codon change SFSs in a dictionary to a .TXT file
# SFSs exported to : dgrp2_downsampled_sfss_150.txt
# Exporting codon change SFSs in a dictionary to a .TXT file
# SFSs exported to : dpgp3_downsampled_sfss_150.txt

# %%
# Out:
# backp_parsimony_only_roots     dpgp3_downsampled_sfss.json
# dgrp2_downsampled_sfss.json    dpgp3_downsampled_sfss.pickle
# dgrp2_downsampled_sfss.pickle  dpgp3_downsampled_sfss_150.txt
# dgrp2_downsampled_sfss_150.txt dpgp3_downsampled_sfss_25.txt
# dgrp2_downsampled_sfss_25.txt
